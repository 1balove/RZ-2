# %%
import numpy as np
import statsmodels.api as sm
import matplotlib.pyplot as plt

# %%
import pandas as pd
data = pd.read_csv('clear_data/overall_data.csv')

# %%
data
# Out:
#     headline_cpi  core_cpi  inf_expectation  gdp_change  year  quarter  \
# 0            1.1      -4.1              1.5         5.7  1999        4
# 1            0.8       3.7              2.3         4.9  2000        1
# 2            0.6      -3.1              2.4         2.8  2000        2
# 3            0.8       4.8              2.2         2.4  2000        3
# 4            1.0      -3.1              2.3         2.4  2000        4
# ..           ...       ...              ...         ...   ...      ...
# 92          10.7       0.0              4.8         1.2  2022        4
# 93          10.2      14.3              3.9         0.4  2023        1
# 94           8.4       5.2              3.5         0.0  2023        2
# 95           6.7       3.8              3.6        -0.4  2023        3
# 96           4.2      -0.9              3.3        -1.2  2023        4
#
#     potential_gdp  output_gap  unemployment
# 0   436612.737794    0.568069           5.8
# ...

# %%
inf_ex = data["inf_expectation"]
inf_ex
# Out:
# 0     1.5
# 1     2.3
# 2     2.4
# 3     2.2
# 4     2.3
#      ...
# 92    4.8
# 93    3.9
# 94    3.5
# 95    3.6
# 96    3.3
# Name: inf_expectation, Length: 97, dtype: float64

# %%
data["int_ex_forecast"] = data["inf_expectation"].rolling(4).mean().shift(1)

# %%
data
# Out:
#     headline_cpi  core_cpi  inf_expectation  gdp_change  year  quarter  \
# 0            1.1      -4.1              1.5         5.7  1999        4
# 1            0.8       3.7              2.3         4.9  2000        1
# 2            0.6      -3.1              2.4         2.8  2000        2
# 3            0.8       4.8              2.2         2.4  2000        3
# 4            1.0      -3.1              2.3         2.4  2000        4
# ..           ...       ...              ...         ...   ...      ...
# 92          10.7       0.0              4.8         1.2  2022        4
# 93          10.2      14.3              3.9         0.4  2023        1
# 94           8.4       5.2              3.5         0.0  2023        2
# 95           6.7       3.8              3.6        -0.4  2023        3
# 96           4.2      -0.9              3.3        -1.2  2023        4
#
#     potential_gdp  output_gap  unemployment  int_ex_forecast
# ...

# %%
data = data.dropna()

# %%
data
# Out:
#     headline_cpi  core_cpi  inf_expectation  gdp_change  year  quarter  \
# 4            1.0      -3.1              2.3         2.4  2000        4
# 5            0.9       4.8              2.1         3.6  2001        1
# 6            1.5       0.0              2.1         1.6  2001        2
# 7            1.5       3.1              2.2         2.0  2001        3
# 8            1.0      -1.0              1.9         1.2  2001        4
# ..           ...       ...              ...         ...   ...      ...
# 92          10.7       0.0              4.8         1.2  2022        4
# 93          10.2      14.3              3.9         0.4  2023        1
# 94           8.4       5.2              3.5         0.0  2023        2
# 95           6.7       3.8              3.6        -0.4  2023        3
# 96           4.2      -0.9              3.3        -1.2  2023        4
#
#     potential_gdp  output_gap  unemployment  int_ex_forecast
# ...
