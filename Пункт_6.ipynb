# %% [markdown]
# Пункт 6
#
# Спецификация 5

# %%
import numpy as np
import statsmodels.api as sm
import matplotlib.pyplot as plt
import pandas as pd

# %%
data = pd.read_csv('clear_data/overall_data.csv')
cpi = data['headline_cpi']
data['g_t_lag1'] = data['headline_cpi'].shift(1)
data['g_t_lag2'] = data['headline_cpi'].shift(2)
data['g_t_lag3'] = data['headline_cpi'].shift(3)
data['g_t_lag4'] = data['headline_cpi'].shift(4)
data['g_t_lead4'] = data['headline_cpi'].shift(-4)
data['x_t-1'] = data['output_gap'].shift(1)
data = data.dropna()
data
# Out:
#     headline_cpi  core_cpi  inf_expectation  gdp_change  year  quarter  \
# 4            1.0      -3.1              2.3         2.4  2000        4
# 5            0.9       4.8              2.1         3.6  2001        1
# 6            1.5       0.0              2.1         1.6  2001        2
# 7            1.5       3.1              2.2         2.0  2001        3
# 8            1.0      -1.0              1.9         1.2  2001        4
# ..           ...       ...              ...         ...   ...      ...
# 88           4.9       2.5              3.2         6.1  2021        4
# 89           6.2       9.8              4.3         2.8  2022        1
# 90           9.2       5.2              4.6         1.2  2022        2
# 91          10.0       8.3              4.9         0.4  2022        3
# 92          10.7       0.0              4.8         1.2  2022        4
#
#     potential_gdp  output_gap  unemployment  g_t_lag1  g_t_lag2  g_t_lag3  \
# 4   450902.911771    0.564221           5.2       0.8       0.6       0.8
# 5   454374.410251    0.727504           5.1       1.0       0.8       0.6
# 6   457804.900937    0.396479           5.0       0.9       1.0       0.8
# 7   461197.486996    0.177476           5.1       1.5       0.9       1.0
# 8   464556.406028   -0.248066           5.2       1.5       1.5       0.9
# ..            ...         ...           ...       ...       ...       ...
# 88  612081.560709    2.043917           4.2       2.8       2.1       0.6
# 89  614640.395796    2.360503           3.9       4.9       2.8       2.1
# 90  617281.501945    2.264202           3.9       6.2       4.9       2.8
# 91  619971.888540    1.936396           3.8       9.2       6.2       4.9
# 92  622687.300277    1.823821           3.9      10.0       9.2       6.2
#
#     g_t_lag4  g_t_lead4     x_t-1
# 4        1.1        1.0  0.737307
# 5        0.8        1.5  0.564221
# 6        0.6        0.9  0.727504
# 7        0.8        1.0  0.396479
# 8        1.0        1.5  0.177476
# ..       ...        ...       ...
# 88       0.5       10.7  0.953329
# 89       0.6       10.2  2.043917
# 90       2.1        8.4  2.360503
# 91       2.8        6.7  2.264202
# 92       4.9        4.2  1.936396
#
# [89 rows x 15 columns]

# %%
data['diff_t'] = data['headline_cpi'] - data['g_t_lag1']
data['diff_t1'] = data['g_t_lag1'] - data['g_t_lag2']
data['diff_t2'] = data['g_t_lag2'] - data['g_t_lag3']
data['diff_t3'] = data['g_t_lag3'] - data['g_t_lag4']
data['y_t'] = data['g_t_lead4'] - data['headline_cpi']
data
# Out:
#     headline_cpi  core_cpi  inf_expectation  gdp_change  year  quarter  \
# 4            1.0      -3.1              2.3         2.4  2000        4
# 5            0.9       4.8              2.1         3.6  2001        1
# 6            1.5       0.0              2.1         1.6  2001        2
# 7            1.5       3.1              2.2         2.0  2001        3
# 8            1.0      -1.0              1.9         1.2  2001        4
# ..           ...       ...              ...         ...   ...      ...
# 88           4.9       2.5              3.2         6.1  2021        4
# 89           6.2       9.8              4.3         2.8  2022        1
# 90           9.2       5.2              4.6         1.2  2022        2
# 91          10.0       8.3              4.9         0.4  2022        3
# 92          10.7       0.0              4.8         1.2  2022        4
#
#     potential_gdp  output_gap  unemployment  g_t_lag1  g_t_lag2  g_t_lag3  \
# 4   450902.911771    0.564221           5.2       0.8       0.6       0.8
# 5   454374.410251    0.727504           5.1       1.0       0.8       0.6
# 6   457804.900937    0.396479           5.0       0.9       1.0       0.8
# 7   461197.486996    0.177476           5.1       1.5       0.9       1.0
# 8   464556.406028   -0.248066           5.2       1.5       1.5       0.9
# ..            ...         ...           ...       ...       ...       ...
# 88  612081.560709    2.043917           4.2       2.8       2.1       0.6
# 89  614640.395796    2.360503           3.9       4.9       2.8       2.1
# 90  617281.501945    2.264202           3.9       6.2       4.9       2.8
# 91  619971.888540    1.936396           3.8       9.2       6.2       4.9
# 92  622687.300277    1.823821           3.9      10.0       9.2       6.2
#
#     g_t_lag4  g_t_lead4     x_t-1  diff_t  diff_t1  diff_t2  diff_t3  y_t
# 4        1.1        1.0  0.737307     0.2      0.2     -0.2     -0.3  0.0
# 5        0.8        1.5  0.564221    -0.1      0.2      0.2     -0.2  0.6
# 6        0.6        0.9  0.727504     0.6     -0.1      0.2      0.2 -0.6
# 7        0.8        1.0  0.396479     0.0      0.6     -0.1      0.2 -0.5
# 8        1.0        1.5  0.177476    -0.5      0.0      0.6     -0.1  0.5
# ..       ...        ...       ...     ...      ...      ...      ...  ...
# 88       0.5       10.7  0.953329     2.1      0.7      1.5      0.1  5.8
# 89       0.6       10.2  2.043917     1.3      2.1      0.7      1.5  4.0
# 90       2.1        8.4  2.360503     3.0      1.3      2.1      0.7 -0.8
# 91       2.8        6.7  2.264202     0.8      3.0      1.3      2.1 -3.3
# 92       4.9        4.2  1.936396     0.7      0.8      3.0      1.3 -6.5
#
# [89 rows x 20 columns]

# %%
X = data[['diff_t', 'diff_t1', 'diff_t2', 'diff_t3', 'x_t-1']]
X = sm.add_constant(X)  # свободного члена
y = data['y_t']
model_spec5 = sm.OLS(y, X).fit()
print(model_spec5.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    y_t   R-squared:                       0.221
# Model:                            OLS   Adj. R-squared:                  0.174
# Method:                 Least Squares   F-statistic:                     4.717
# Date:                Mon, 25 Nov 2024   Prob (F-statistic):           0.000767
# Time:                        00:45:29   Log-Likelihood:                -176.94
# No. Observations:                  89   AIC:                             365.9
# Df Residuals:                      83   BIC:                             380.8
# Df Model:                           5
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.2499      0.199      1.258      0.212      -0.145       0.645
# diff_t         0.6338      0.348      1.823      0.072      -0.058       1.325
# diff_t1        0.1875      0.385      0.487      0.628      -0.578       0.953
# diff_t2       -0.7652      0.378     -2.025      0.046      -1.517      -0.013
# diff_t3       -0.0731      0.402     -0.182      0.856      -0.873       0.726
# x_t-1         -0.2605      0.072     -3.615      0.001      -0.404      -0.117
# ==============================================================================
# Omnibus:                       17.863   Durbin-Watson:                   0.690
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               26.114
# Skew:                           0.876   Prob(JB):                     2.14e-06
# Kurtosis:                       4.993   Cond. No.                         6.87
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
spec5_pred = model_spec5.predict(X)
print(spec5_pred, '\n min                max')
print(spec5_pred.min(), spec5_pred.max())
# Out:
# 4     0.397119
# 5    -0.061327
# 6     0.254287
# 7     0.321071
# 8    -0.564997
#         ...
# 88    0.308676
# 89    0.289882
# 90    0.122026
# 91   -0.418635
# 92   -2.051526
# Length: 89, dtype: float64
#  min                max
# -2.051526311691271 5.012047601349994

# %%
data['spec5_pred'] = spec5_pred

# %%
res_data = data
res_data
# Out:
#     headline_cpi  core_cpi  inf_expectation  gdp_change  year  quarter  \
# 4            1.0      -3.1              2.3         2.4  2000        4
# 5            0.9       4.8              2.1         3.6  2001        1
# 6            1.5       0.0              2.1         1.6  2001        2
# 7            1.5       3.1              2.2         2.0  2001        3
# 8            1.0      -1.0              1.9         1.2  2001        4
# ..           ...       ...              ...         ...   ...      ...
# 88           4.9       2.5              3.2         6.1  2021        4
# 89           6.2       9.8              4.3         2.8  2022        1
# 90           9.2       5.2              4.6         1.2  2022        2
# 91          10.0       8.3              4.9         0.4  2022        3
# 92          10.7       0.0              4.8         1.2  2022        4
#
#     potential_gdp  output_gap  unemployment  g_t_lag1  ...  g_t_lag3  \
# 4   450902.911771    0.564221           5.2       0.8  ...       0.8
# 5   454374.410251    0.727504           5.1       1.0  ...       0.6
# 6   457804.900937    0.396479           5.0       0.9  ...       0.8
# 7   461197.486996    0.177476           5.1       1.5  ...       1.0
# 8   464556.406028   -0.248066           5.2       1.5  ...       0.9
# ..            ...         ...           ...       ...  ...       ...
# 88  612081.560709    2.043917           4.2       2.8  ...       0.6
# 89  614640.395796    2.360503           3.9       4.9  ...       2.1
# 90  617281.501945    2.264202           3.9       6.2  ...       2.8
# 91  619971.888540    1.936396           3.8       9.2  ...       4.9
# 92  622687.300277    1.823821           3.9      10.0  ...       6.2
#
#     g_t_lag4  g_t_lead4     x_t-1  diff_t  diff_t1  diff_t2  diff_t3  y_t  \
# 4        1.1        1.0  0.737307     0.2      0.2     -0.2     -0.3  0.0
# 5        0.8        1.5  0.564221    -0.1      0.2      0.2     -0.2  0.6
# 6        0.6        0.9  0.727504     0.6     -0.1      0.2      0.2 -0.6
# 7        0.8        1.0  0.396479     0.0      0.6     -0.1      0.2 -0.5
# 8        1.0        1.5  0.177476    -0.5      0.0      0.6     -0.1  0.5
# ..       ...        ...       ...     ...      ...      ...      ...  ...
# 88       0.5       10.7  0.953329     2.1      0.7      1.5      0.1  5.8
# 89       0.6       10.2  2.043917     1.3      2.1      0.7      1.5  4.0
# 90       2.1        8.4  2.360503     3.0      1.3      2.1      0.7 -0.8
# 91       2.8        6.7  2.264202     0.8      3.0      1.3      2.1 -3.3
# 92       4.9        4.2  1.936396     0.7      0.8      3.0      1.3 -6.5
#
#     spec5_pred
# 4     0.397119
# 5    -0.061327
# 6     0.254287
# 7     0.321071
# 8    -0.564997
# ..         ...
# 88    0.308676
# 89    0.289882
# 90    0.122026
# 91   -0.418635
# 92   -2.051526
#
# [89 rows x 21 columns]

# %% [markdown]
# Спецификация 6

# %%
data = pd.read_csv('clear_data/overall_data.csv')
cpi = data['headline_cpi']
data['g_t_lag1'] = data['headline_cpi'].shift(1)
data['g_t_lag2'] = data['headline_cpi'].shift(2)
data['g_t_lag3'] = data['headline_cpi'].shift(3)
data['g_t_lag4'] = data['headline_cpi'].shift(4)
data['g_t_lead4'] = data['headline_cpi'].shift(-4)
data['x_t-1'] = data['gdp_change'].shift(1)
data = data.dropna()
data
# Out:
#     headline_cpi  core_cpi  inf_expectation  gdp_change  year  quarter  \
# 4            1.0      -3.1              2.3         2.4  2000        4
# 5            0.9       4.8              2.1         3.6  2001        1
# 6            1.5       0.0              2.1         1.6  2001        2
# 7            1.5       3.1              2.2         2.0  2001        3
# 8            1.0      -1.0              1.9         1.2  2001        4
# ..           ...       ...              ...         ...   ...      ...
# 88           4.9       2.5              3.2         6.1  2021        4
# 89           6.2       9.8              4.3         2.8  2022        1
# 90           9.2       5.2              4.6         1.2  2022        2
# 91          10.0       8.3              4.9         0.4  2022        3
# 92          10.7       0.0              4.8         1.2  2022        4
#
#     potential_gdp  output_gap  unemployment  g_t_lag1  g_t_lag2  g_t_lag3  \
# 4   450902.911771    0.564221           5.2       0.8       0.6       0.8
# 5   454374.410251    0.727504           5.1       1.0       0.8       0.6
# 6   457804.900937    0.396479           5.0       0.9       1.0       0.8
# 7   461197.486996    0.177476           5.1       1.5       0.9       1.0
# 8   464556.406028   -0.248066           5.2       1.5       1.5       0.9
# ..            ...         ...           ...       ...       ...       ...
# 88  612081.560709    2.043917           4.2       2.8       2.1       0.6
# 89  614640.395796    2.360503           3.9       4.9       2.8       2.1
# 90  617281.501945    2.264202           3.9       6.2       4.9       2.8
# 91  619971.888540    1.936396           3.8       9.2       6.2       4.9
# 92  622687.300277    1.823821           3.9      10.0       9.2       6.2
#
#     g_t_lag4  g_t_lead4  x_t-1
# 4        1.1        1.0    2.4
# 5        0.8        1.5    2.4
# 6        0.6        0.9    3.6
# 7        0.8        1.0    1.6
# 8        1.0        1.5    2.0
# ..       ...        ...    ...
# 88       0.5       10.7    7.0
# 89       0.6       10.2    6.1
# 90       2.1        8.4    2.8
# 91       2.8        6.7    1.2
# 92       4.9        4.2    0.4
#
# [89 rows x 15 columns]

# %%
data['diff_t'] = data['headline_cpi'] - data['g_t_lag1']
data['diff_t1'] = data['g_t_lag1'] - data['g_t_lag2']
data['diff_t2'] = data['g_t_lag2'] - data['g_t_lag3']
data['diff_t3'] = data['g_t_lag3'] - data['g_t_lag4']
data['y_t'] = data['g_t_lead4'] - data['headline_cpi']
data
# Out:
#     headline_cpi  core_cpi  inf_expectation  gdp_change  year  quarter  \
# 4            1.0      -3.1              2.3         2.4  2000        4
# 5            0.9       4.8              2.1         3.6  2001        1
# 6            1.5       0.0              2.1         1.6  2001        2
# 7            1.5       3.1              2.2         2.0  2001        3
# 8            1.0      -1.0              1.9         1.2  2001        4
# ..           ...       ...              ...         ...   ...      ...
# 88           4.9       2.5              3.2         6.1  2021        4
# 89           6.2       9.8              4.3         2.8  2022        1
# 90           9.2       5.2              4.6         1.2  2022        2
# 91          10.0       8.3              4.9         0.4  2022        3
# 92          10.7       0.0              4.8         1.2  2022        4
#
#     potential_gdp  output_gap  unemployment  g_t_lag1  g_t_lag2  g_t_lag3  \
# 4   450902.911771    0.564221           5.2       0.8       0.6       0.8
# 5   454374.410251    0.727504           5.1       1.0       0.8       0.6
# 6   457804.900937    0.396479           5.0       0.9       1.0       0.8
# 7   461197.486996    0.177476           5.1       1.5       0.9       1.0
# 8   464556.406028   -0.248066           5.2       1.5       1.5       0.9
# ..            ...         ...           ...       ...       ...       ...
# 88  612081.560709    2.043917           4.2       2.8       2.1       0.6
# 89  614640.395796    2.360503           3.9       4.9       2.8       2.1
# 90  617281.501945    2.264202           3.9       6.2       4.9       2.8
# 91  619971.888540    1.936396           3.8       9.2       6.2       4.9
# 92  622687.300277    1.823821           3.9      10.0       9.2       6.2
#
#     g_t_lag4  g_t_lead4  x_t-1  diff_t  diff_t1  diff_t2  diff_t3  y_t
# 4        1.1        1.0    2.4     0.2      0.2     -0.2     -0.3  0.0
# 5        0.8        1.5    2.4    -0.1      0.2      0.2     -0.2  0.6
# 6        0.6        0.9    3.6     0.6     -0.1      0.2      0.2 -0.6
# 7        0.8        1.0    1.6     0.0      0.6     -0.1      0.2 -0.5
# 8        1.0        1.5    2.0    -0.5      0.0      0.6     -0.1  0.5
# ..       ...        ...    ...     ...      ...      ...      ...  ...
# 88       0.5       10.7    7.0     2.1      0.7      1.5      0.1  5.8
# 89       0.6       10.2    6.1     1.3      2.1      0.7      1.5  4.0
# 90       2.1        8.4    2.8     3.0      1.3      2.1      0.7 -0.8
# 91       2.8        6.7    1.2     0.8      3.0      1.3      2.1 -3.3
# 92       4.9        4.2    0.4     0.7      0.8      3.0      1.3 -6.5
#
# [89 rows x 20 columns]

# %%
X = data[['diff_t', 'diff_t1', 'diff_t2', 'diff_t3', 'x_t-1']]
X = sm.add_constant(X)  # свободного члена
y = data['y_t']
model_spec6 = sm.OLS(y, X).fit()
print(model_spec6.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    y_t   R-squared:                       0.138
# Model:                            OLS   Adj. R-squared:                  0.086
# Method:                 Least Squares   F-statistic:                     2.665
# Date:                Mon, 25 Nov 2024   Prob (F-statistic):             0.0277
# Time:                        00:45:29   Log-Likelihood:                -181.45
# No. Observations:                  89   AIC:                             374.9
# Df Residuals:                      83   BIC:                             389.8
# Df Model:                           5
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.2211      0.212      1.043      0.300      -0.201       0.643
# diff_t         0.7045      0.365      1.930      0.057      -0.021       1.430
# diff_t1       -0.3292      0.406     -0.810      0.420      -1.138       0.479
# diff_t2       -0.5361      0.415     -1.290      0.201      -1.362       0.290
# diff_t3       -0.3236      0.423     -0.765      0.446      -1.165       0.517
# x_t-1          0.0359      0.018      1.954      0.054      -0.001       0.072
# ==============================================================================
# Omnibus:                       19.818   Durbin-Watson:                   0.593
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               28.768
# Skew:                           0.979   Prob(JB):                     5.66e-07
# Kurtosis:                       4.982   Cond. No.                         30.0
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
spec6_pred = model_spec6.predict(X)
print(spec6_pred, '\n min                max')
print(spec6_pred.min(), spec6_pred.max())
# Out:
# 4     0.397119
# 5    -0.061327
# 6     0.254287
# 7     0.321071
# 8    -0.564997
#         ...
# 88    0.308676
# 89    0.289882
# 90    0.122026
# 91   -0.418635
# 92   -2.051526
# Length: 89, dtype: float64
#  min                max
# -2.051526311691271 5.012047601349994

# %%
res_data['spec6_pred'] = spec6_pred
res_data
# Out:
#     headline_cpi  core_cpi  inf_expectation  gdp_change  year  quarter  \
# 4            1.0      -3.1              2.3         2.4  2000        4
# 5            0.9       4.8              2.1         3.6  2001        1
# 6            1.5       0.0              2.1         1.6  2001        2
# 7            1.5       3.1              2.2         2.0  2001        3
# 8            1.0      -1.0              1.9         1.2  2001        4
# ..           ...       ...              ...         ...   ...      ...
# 88           4.9       2.5              3.2         6.1  2021        4
# 89           6.2       9.8              4.3         2.8  2022        1
# 90           9.2       5.2              4.6         1.2  2022        2
# 91          10.0       8.3              4.9         0.4  2022        3
# 92          10.7       0.0              4.8         1.2  2022        4
#
#     potential_gdp  output_gap  unemployment  g_t_lag1  ...  g_t_lag4  \
# 4   450902.911771    0.564221           5.2       0.8  ...       1.1
# 5   454374.410251    0.727504           5.1       1.0  ...       0.8
# 6   457804.900937    0.396479           5.0       0.9  ...       0.6
# 7   461197.486996    0.177476           5.1       1.5  ...       0.8
# 8   464556.406028   -0.248066           5.2       1.5  ...       1.0
# ..            ...         ...           ...       ...  ...       ...
# 88  612081.560709    2.043917           4.2       2.8  ...       0.5
# 89  614640.395796    2.360503           3.9       4.9  ...       0.6
# 90  617281.501945    2.264202           3.9       6.2  ...       2.1
# 91  619971.888540    1.936396           3.8       9.2  ...       2.8
# 92  622687.300277    1.823821           3.9      10.0  ...       4.9
#
#     g_t_lead4     x_t-1  diff_t  diff_t1  diff_t2  diff_t3  y_t  spec5_pred  \
# 4         1.0  0.737307     0.2      0.2     -0.2     -0.3  0.0    0.397119
# 5         1.5  0.564221    -0.1      0.2      0.2     -0.2  0.6   -0.061327
# 6         0.9  0.727504     0.6     -0.1      0.2      0.2 -0.6    0.254287
# 7         1.0  0.396479     0.0      0.6     -0.1      0.2 -0.5    0.321071
# 8         1.5  0.177476    -0.5      0.0      0.6     -0.1  0.5   -0.564997
# ..        ...       ...     ...      ...      ...      ...  ...         ...
# 88       10.7  0.953329     2.1      0.7      1.5      0.1  5.8    0.308676
# 89       10.2  2.043917     1.3      2.1      0.7      1.5  4.0    0.289882
# 90        8.4  2.360503     3.0      1.3      2.1      0.7 -0.8    0.122026
# 91        6.7  2.264202     0.8      3.0      1.3      2.1 -3.3   -0.418635
# 92        4.2  1.936396     0.7      0.8      3.0      1.3 -6.5   -2.051526
#
#     spec6_pred
# 4     0.586501
# 5     0.128378
# 6     0.633824
# 7     0.069826
# 8    -0.348690
# ..         ...
# 88    0.884511
# 89   -0.196440
# 90    0.654608
# 91   -1.536433
# 92   -1.563703
#
# [89 rows x 22 columns]

# %% [markdown]
# Спецификация 7

# %%
data = pd.read_csv('clear_data/overall_data.csv')
cpi = data['headline_cpi']
data['g_t_lag1'] = data['headline_cpi'].shift(1)
data['g_t_lag2'] = data['headline_cpi'].shift(2)
data['g_t_lag3'] = data['headline_cpi'].shift(3)
data['g_t_lag4'] = data['headline_cpi'].shift(4)
data['g_t_lead4'] = data['headline_cpi'].shift(-4)
data['x_t-1'] = data['unemployment'].shift(1)
data = data.dropna()
data
# Out:
#     headline_cpi  core_cpi  inf_expectation  gdp_change  year  quarter  \
# 4            1.0      -3.1              2.3         2.4  2000        4
# 5            0.9       4.8              2.1         3.6  2001        1
# 6            1.5       0.0              2.1         1.6  2001        2
# 7            1.5       3.1              2.2         2.0  2001        3
# 8            1.0      -1.0              1.9         1.2  2001        4
# ..           ...       ...              ...         ...   ...      ...
# 88           4.9       2.5              3.2         6.1  2021        4
# 89           6.2       9.8              4.3         2.8  2022        1
# 90           9.2       5.2              4.6         1.2  2022        2
# 91          10.0       8.3              4.9         0.4  2022        3
# 92          10.7       0.0              4.8         1.2  2022        4
#
#     potential_gdp  output_gap  unemployment  g_t_lag1  g_t_lag2  g_t_lag3  \
# 4   450902.911771    0.564221           5.2       0.8       0.6       0.8
# 5   454374.410251    0.727504           5.1       1.0       0.8       0.6
# 6   457804.900937    0.396479           5.0       0.9       1.0       0.8
# 7   461197.486996    0.177476           5.1       1.5       0.9       1.0
# 8   464556.406028   -0.248066           5.2       1.5       1.5       0.9
# ..            ...         ...           ...       ...       ...       ...
# 88  612081.560709    2.043917           4.2       2.8       2.1       0.6
# 89  614640.395796    2.360503           3.9       4.9       2.8       2.1
# 90  617281.501945    2.264202           3.9       6.2       4.9       2.8
# 91  619971.888540    1.936396           3.8       9.2       6.2       4.9
# 92  622687.300277    1.823821           3.9      10.0       9.2       6.2
#
#     g_t_lag4  g_t_lead4  x_t-1
# 4        1.1        1.0    5.3
# 5        0.8        1.5    5.2
# 6        0.6        0.9    5.1
# 7        0.8        1.0    5.0
# 8        1.0        1.5    5.1
# ..       ...        ...    ...
# 88       0.5       10.7    4.4
# 89       0.6       10.2    4.2
# 90       2.1        8.4    3.9
# 91       2.8        6.7    3.9
# 92       4.9        4.2    3.8
#
# [89 rows x 15 columns]

# %%
data['diff_t'] = data['headline_cpi'] - data['g_t_lag1']
data['diff_t1'] = data['g_t_lag1'] - data['g_t_lag2']
data['diff_t2'] = data['g_t_lag2'] - data['g_t_lag3']
data['diff_t3'] = data['g_t_lag3'] - data['g_t_lag4']
data['y_t'] = data['g_t_lead4'] - data['headline_cpi']
data
# Out:
#     headline_cpi  core_cpi  inf_expectation  gdp_change  year  quarter  \
# 4            1.0      -3.1              2.3         2.4  2000        4
# 5            0.9       4.8              2.1         3.6  2001        1
# 6            1.5       0.0              2.1         1.6  2001        2
# 7            1.5       3.1              2.2         2.0  2001        3
# 8            1.0      -1.0              1.9         1.2  2001        4
# ..           ...       ...              ...         ...   ...      ...
# 88           4.9       2.5              3.2         6.1  2021        4
# 89           6.2       9.8              4.3         2.8  2022        1
# 90           9.2       5.2              4.6         1.2  2022        2
# 91          10.0       8.3              4.9         0.4  2022        3
# 92          10.7       0.0              4.8         1.2  2022        4
#
#     potential_gdp  output_gap  unemployment  g_t_lag1  g_t_lag2  g_t_lag3  \
# 4   450902.911771    0.564221           5.2       0.8       0.6       0.8
# 5   454374.410251    0.727504           5.1       1.0       0.8       0.6
# 6   457804.900937    0.396479           5.0       0.9       1.0       0.8
# 7   461197.486996    0.177476           5.1       1.5       0.9       1.0
# 8   464556.406028   -0.248066           5.2       1.5       1.5       0.9
# ..            ...         ...           ...       ...       ...       ...
# 88  612081.560709    2.043917           4.2       2.8       2.1       0.6
# 89  614640.395796    2.360503           3.9       4.9       2.8       2.1
# 90  617281.501945    2.264202           3.9       6.2       4.9       2.8
# 91  619971.888540    1.936396           3.8       9.2       6.2       4.9
# 92  622687.300277    1.823821           3.9      10.0       9.2       6.2
#
#     g_t_lag4  g_t_lead4  x_t-1  diff_t  diff_t1  diff_t2  diff_t3  y_t
# 4        1.1        1.0    5.3     0.2      0.2     -0.2     -0.3  0.0
# 5        0.8        1.5    5.2    -0.1      0.2      0.2     -0.2  0.6
# 6        0.6        0.9    5.1     0.6     -0.1      0.2      0.2 -0.6
# 7        0.8        1.0    5.0     0.0      0.6     -0.1      0.2 -0.5
# 8        1.0        1.5    5.1    -0.5      0.0      0.6     -0.1  0.5
# ..       ...        ...    ...     ...      ...      ...      ...  ...
# 88       0.5       10.7    4.4     2.1      0.7      1.5      0.1  5.8
# 89       0.6       10.2    4.2     1.3      2.1      0.7      1.5  4.0
# 90       2.1        8.4    3.9     3.0      1.3      2.1      0.7 -0.8
# 91       2.8        6.7    3.9     0.8      3.0      1.3      2.1 -3.3
# 92       4.9        4.2    3.8     0.7      0.8      3.0      1.3 -6.5
#
# [89 rows x 20 columns]

# %%
X = data[['diff_t', 'diff_t1', 'diff_t2', 'diff_t3', 'x_t-1']]
X = sm.add_constant(X)  # свободного члена
y = data['y_t']
model_spec7 = sm.OLS(y, X).fit()
print(model_spec7.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    y_t   R-squared:                       0.117
# Model:                            OLS   Adj. R-squared:                  0.064
# Method:                 Least Squares   F-statistic:                     2.199
# Date:                Mon, 25 Nov 2024   Prob (F-statistic):             0.0620
# Time:                        00:45:29   Log-Likelihood:                -182.54
# No. Observations:                  89   AIC:                             377.1
# Df Residuals:                      83   BIC:                             392.0
# Df Model:                           5
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          1.5077      0.948      1.590      0.116      -0.379       3.394
# diff_t         0.6615      0.373      1.774      0.080      -0.080       1.403
# diff_t1       -0.1745      0.400     -0.436      0.664      -0.970       0.621
# diff_t2       -0.8227      0.404     -2.034      0.045      -1.627      -0.018
# diff_t3       -0.2785      0.427     -0.652      0.516      -1.127       0.570
# x_t-1         -0.2131      0.163     -1.311      0.194      -0.537       0.110
# ==============================================================================
# Omnibus:                       22.359   Durbin-Watson:                   0.506
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               34.635
# Skew:                           1.063   Prob(JB):                     3.01e-08
# Kurtosis:                       5.195   Cond. No.                         27.3
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
spec7_pred = model_spec7.predict(X)
print(spec7_pred, '\n min                max')
print(spec7_pred.min(), spec7_pred.max())
# Out:
# 4     0.723533
# 5     0.189504
# 6     0.614818
# 7     0.363877
# 8    -0.375763
#         ...
# 88    0.574962
# 89    0.112361
# 90    0.511455
# 91   -0.972173
# 92   -1.808767
# Length: 89, dtype: float64
#  min                max
# -1.8087665342325538 1.4777062545701232

# %%
res_data['spec7_pred'] = spec7_pred
res_data = res_data[['year', 'quarter', 'spec5_pred', 'spec6_pred', 'spec7_pred']]
res_data
# Out:
#     year  quarter  spec5_pred  spec6_pred  spec7_pred
# 4   2000        4    0.397119    0.586501    0.723533
# 5   2001        1   -0.061327    0.128378    0.189504
# 6   2001        2    0.254287    0.633824    0.614818
# 7   2001        3    0.321071    0.069826    0.363877
# 8   2001        4   -0.564997   -0.348690   -0.375763
# ..   ...      ...         ...         ...         ...
# 88  2021        4    0.308676    0.884511    0.574962
# 89  2022        1    0.289882   -0.196440    0.112361
# 90  2022        2    0.122026    0.654608    0.511455
# 91  2022        3   -0.418635   -1.536433   -0.972173
# 92  2022        4   -2.051526   -1.563703   -1.808767
#
# [89 rows x 5 columns]

# %%
res_data.to_csv('clear_data/task6_res.csv')
