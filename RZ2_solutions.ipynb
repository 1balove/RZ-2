# %% [markdown]
# 2 задание

# %%
import scipy.stats as stats

# %%
import pandas as pd

overall_data = pd.read_csv('clear_data/overall_data.csv')
overall_data
# Out:
#     headline_cpi  core_cpi  inf_expectation  gdp  year  quarter  \
# 0            1.1      -4.1              1.5  5.7  1999        4
# 1            0.8       3.7              2.3  4.9  2000        1
# 2            0.6      -3.1              2.4  2.8  2000        2
# 3            0.8       4.8              2.2  2.4  2000        3
# 4            1.0      -3.1              2.3  2.4  2000        4
# ..           ...       ...              ...  ...   ...      ...
# 92          10.7       0.0              4.8  1.2  2022        4
# 93          10.2      14.3              3.9  0.4  2023        1
# 94           8.4       5.2              3.5  0.0  2023        2
# 95           6.7       3.8              3.6 -0.4  2023        3
# 96           4.2      -0.9              3.3 -1.2  2023        4
#
#     potential_gdp  output_gap  unemployment
# 0        3.385730   68.353654           5.8
# 1        3.330380   47.130344           5.8
# 2        3.268623  -14.337013           5.5
# 3        3.203238  -25.075807           5.3
# 4        3.136712  -23.486755           5.2
# ..            ...         ...           ...
# 92       3.335138  -64.019477           3.9
# 93       3.027886  -86.789462           4.0
# 94       2.711156 -100.000000           4.2
# 95       2.389843 -116.737499           4.1
# 96       2.067148 -158.050983           3.8
#
# [97 rows x 9 columns]

# %%
minimum = overall_data.drop(columns=['year', 'quarter']).min()
maximum = overall_data.drop(columns=['year', 'quarter']).max()
median = overall_data.drop(columns=['year', 'quarter']).median()
std = overall_data.drop(columns=['year', 'quarter']).std()
mean = overall_data.drop(columns=['year', 'quarter']).mean()
skew = overall_data.drop(columns=['year', 'quarter']).apply(stats.skew)
mode = overall_data.drop(columns=['year', 'quarter']).apply(stats.mode)

statistics = pd.DataFrame({
    'min' : minimum,
    'max' : maximum,
    'median' : median,
    'mean' : mean,
    'mode' : mode.transpose()[0],
    'std' : std,
    'skew' : skew
})
statistics
# Out:
#                          min          max    median        mean        mode  \
# headline_cpi        0.000000    10.700000  2.100000    2.510309    1.500000
# core_cpi           -4.100000    14.300000  2.600000    2.131959   -0.000000
# inf_expectation     1.500000     4.900000  2.700000    2.856701    2.200000
# gdp               -59.700000    86.100000  2.400000    2.207216    2.800000
# potential_gdp       0.114785     4.507451  2.183535    2.222684    0.114785
# output_gap      -6895.317795  1927.951462  4.351891 -151.344298 -100.000000
# unemployment        3.800000     8.400000  5.200000    5.517526    5.200000
#
#                          std      skew
# headline_cpi        2.124828  2.113118
# core_cpi            3.191772  0.528629
# inf_expectation     0.723404  0.809844
# gdp                11.403465  2.657939
# potential_gdp       1.130492 -0.035251
# output_gap       1061.480092 -5.034695
# unemployment        1.338377  0.830323

# %%
statistics.to_csv('clear_data/statistics.csv')
